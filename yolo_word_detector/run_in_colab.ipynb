# %% [markdown]
# # Runner cell for google colab

# %% [markdown]
# 1

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import sys

# Reset and Clone
os.chdir('/content')
# !rm -rf Ka-OCR
# !git clone https://github.com/irakliskhirtladze/Ka-OCR.git
# %cd /content/Ka-OCR/word_detection

# Install uv
# !curl -LsSf https://astral.sh/uv/install.sh | sh
os.environ['PATH'] = f"{os.environ['HOME']}/.cargo/bin:{os.environ['PATH']}"

# Create a "Bridge" Venv
# --system-site-packages allows the venv to see 'google.colab'
# !uv venv .venv --system-site-packages

# Install your repo into the venv
# uv will automatically use the .venv it just created
# !uv pip install -e .

# Inject the venv into the current session
# This avoids needing to "switch kernels" manually
venv_path = "/content/Ka-OCR/word_detection/.venv/lib/python3.12/site-packages"
if venv_path not in sys.path:
    sys.path.insert(0, venv_path)

# # Launch the dashboard pointing to your output directory
# %load_ext tensorboard
# %tensorboard --logdir "/content/drive/MyDrive/Colab Notebooks/trocr-ka/output/logs"

# !uv run main
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#       4 import os
#
# ModuleNotFoundError: No module named 'google'
